# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(6,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()), list(fifa['nationality'].value_counts()[0:5]),color='y')
plt.show()

# %%
player_salary = fifa[['short_name', 'wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
plt.figure(figsize = (6,5))
plt.bar(list(player_salary['short_name'])[0:5], list(player_salary['wage_eur'][0:5]),color='r')
plt.show()

# %%
fifa['nationality'] == 'Brazil'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Brazil = fifa[fifa['nationality'] == 'Brazil']
Brazil.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 2      190871  https://sofifa.com/player/190871/neymar-da-sil...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 25     210257  https://sofifa.com/player/210257/ederson-santa...
# 42     200145  https://sofifa.com/player/200145/carlos-henriq...
# 44     135507  https://sofifa.com/player/135507/fernando-luiz...
# 45     164240  https://sofifa.com/player/164240/thiago-emilia...
# 56     207865  https://sofifa.com/player/207865/marcos-aoas-c...
# 63     201942  https://sofifa.com/player/201942/roberto-firmi...
# 68     189242  https://sofifa.com/player/189242/philippe-cout...
# 81     209499  https://sofifa.com/player/209499/fabio-henriqu...
#
#          short_name                            long_name  age         dob  \
# 2         Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 13          Alisson                Alisson Ramses Becker   26  1992-10-02
# ...

# %%
Brazil.sort_values(by=['height_cm'], ascending = False).head()
# Out:
#       sofifa_id                                         player_url  \
# 506      171919  https://sofifa.com/player/171919/ronaldo-apare...
# 2800     238224  https://sofifa.com/player/238224/amaral-alves-...
# 4337     213951  https://sofifa.com/player/213951/helton-brant-...
# 9442     207708  https://sofifa.com/player/207708/fabio-szymone...
# 4742     234670  https://sofifa.com/player/234670/jorge-fellipe...
#
#          short_name                           long_name  age         dob  \
# 506           Naldo        Ronaldo  Aparecido Rodrigues   36  1982-09-10
# 2800         Marcão        Amaral Alves Marcos Vinicius   25  1994-06-16
# 4337   Helton Leite           Helton Brant Aleixo Leite   28  1990-11-02
# 9442          Fábio                      Fábio Szymonek   29  1990-05-11
# 4742  Jorge Fellipe  Jorge Fellipe de Oliveira Figueiro   30  1988-10-27
#
#       height_cm  weight_kg nationality                    club  ...   lwb  \
# ...

# %%
Brazil.sort_values(by=['weight_kg'], ascending = False).head()
# Out:
#       sofifa_id                                         player_url  \
# 4020     230516  https://sofifa.com/player/230516/paulao-paulo-...
# 1429     135451  https://sofifa.com/player/135451/heurelho-silv...
# 600      232381  https://sofifa.com/player/232381/wesley-moraes...
# 6963     207899  https://sofifa.com/player/207899/alvino-volpi-...
# 273      195093  https://sofifa.com/player/195093/willian-jose-...
#
#              short_name                        long_name  age         dob  \
# 4020  Paulao Junqueiras    Paulao Paulo Junqueiras Couto   31  1988-02-29
# 1429              Gomes          Heurelho da Silva Gomes   38  1981-02-15
# 600              Wesley  Wesley Moraes Ferreira da Silva   22  1996-11-26
# 6963               Neto                Alvino Volpi Neto   26  1992-08-01
# 273        Willian José            Willian José da Silva   27  1991-11-23
#
#       height_cm  weight_kg nationality             club  ...   lwb   ldm  \
# ...

# %%
Brazil.sort_values(by=['wage_eur'], ascending = False).head()
# Out:
#      sofifa_id                                         player_url  \
# 2       190871  https://sofifa.com/player/190871/neymar-da-sil...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 101     176676  https://sofifa.com/player/176676/marcelo-vieir...
# 44      135507  https://sofifa.com/player/135507/fernando-luiz...
# 25      210257  https://sofifa.com/player/210257/ederson-santa...
#
#       short_name                          long_name  age         dob  \
# 2      Neymar Jr      Neymar da Silva Santos Junior   27  1992-02-05
# 42      Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 101      Marcelo     Marcelo Vieira da Silva Júnior   31  1988-05-12
# 44   Fernandinho                 Fernando Luiz Rosa   34  1985-05-04
# 25       Ederson          Ederson Santana de Moraes   25  1993-08-17
#
#      height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
Brazil[['short_name','wage_eur']].sort_values(by=['wage_eur'], ascending = False).head()
# Out:
#       short_name  wage_eur
# 2      Neymar Jr    290000
# 42      Casemiro    240000
# 101      Marcelo    205000
# 44   Fernandinho    200000
# 25       Ederson    185000

# %%
player_shooting = fifa[['short_name', 'shooting']]
player_shooting.head(10)
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0
# 5       K. De Bruyne      86.0
# 6      M. ter Stegen       NaN
# 7        V. van Dijk      60.0
# 8          L. Modrić      76.0
# 9           M. Salah      86.0

# %%
player_shooting.sort_values(by=['shooting'], ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
player_dribbling = fifa[['short_name', 'dribbling']]
player_dribbling.head(10)
# Out:
#           short_name  dribbling
# 0           L. Messi       96.0
# 1  Cristiano Ronaldo       89.0
# 2          Neymar Jr       95.0
# 3           J. Oblak        NaN
# 4          E. Hazard       94.0
# 5       K. De Bruyne       86.0
# 6      M. ter Stegen        NaN
# 7        V. van Dijk       71.0
# 8          L. Modrić       89.0
# 9           M. Salah       89.0

# %%
player_dribbling.sort_values(by=['dribbling'], ascending=False).head(10)
# Out:
#          short_name  dribbling
# 0          L. Messi       96.0
# 2         Neymar Jr       95.0
# 4         E. Hazard       94.0
# 41   Bernardo Silva       92.0
# 150   Douglas Costa       91.0
# 62             Isco       91.0
# 48       D. Mertens       91.0
# 54       L. Insigne       91.0
# 23        P. Dybala       90.0
# 58      M. Verratti       90.0

# %%
player_defending.sort_values(by=['defending'], ascending=False).head(10)
# Out:
#          short_name  defending
# 16     G. Chiellini       90.0
# 7       V. van Dijk       90.0
# 11     K. Koulibaly       89.0
# 35         D. Godín       89.0
# 49       M. Hummels       89.0
# 29            Piqué       88.0
# 50  T. Alderweireld       88.0
# 40       A. Laporte       88.0
# 47    J. Vertonghen       87.0
# 67       L. Bonucci       87.0

# %%
manchester_united=fifa[fifa['club']=='Manchester United']

# %%
manchester_united.sort_values(by=['wage_eur'], ascending = False).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 24      195864  https://sofifa.com/player/195864/paul-pogba/20...
# 14      193080  https://sofifa.com/player/193080/david-de-gea-...
# 301     184941  https://sofifa.com/player/184941/alexis-sanche...
# 163     211300  https://sofifa.com/player/211300/anthony-marti...
# 295     178088  https://sofifa.com/player/178088/juan-manuel-m...
# 319     207494  https://sofifa.com/player/207494/jesse-lingard...
# 171     231677  https://sofifa.com/player/231677/marcus-rashfo...
# 280     203263  https://sofifa.com/player/203263/harry-maguire...
# 534     189881  https://sofifa.com/player/189881/chris-smallin...
# 396     191202  https://sofifa.com/player/191202/nemanja-matic...
#
#       short_name                         long_name  age         dob  \
# 24      P. Pogba                        Paul Pogba   26  1993-03-15
# 14        De Gea             David De Gea Quintana   28  1990-11-07
# ...

# %%
real_madrid=fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['wage_eur'], ascending = False).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8       177003  https://sofifa.com/player/177003/luka-modric/2...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 62      197781  https://sofifa.com/player/197781/francisco-rom...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 28      192119  https://sofifa.com/player/192119/thibaut-court...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
#
#        short_name                          long_name  age         dob  \
# 4       E. Hazard                        Eden Hazard   28  1991-01-07
# 8       L. Modrić                        Luka Modrić   33  1985-09-09
# ...
